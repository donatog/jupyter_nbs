# %% [markdown]
# <a href="https://colab.research.google.com/github/donatog/jupyter_nbs/blob/KOPE/prima.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Programmare in ...
# ![python-software-logo-300x158.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## Il linguaggio di programmazione <b color = "yellow"> python</b>
